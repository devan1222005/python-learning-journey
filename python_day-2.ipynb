# %%
#user input
#add two numbers
a=9
b=10
a+b
# Out:
# 19

# %%
a=input('enter the number')
type(a)
# Out:
# enter the number 9
# str

# %%
a=input('enter the number')
b=input('enter the number')
a+b
# Out:
# enter the number 9
# enter the number 6
# '96'

# %%
'hi'+' python'
# Out:
# 'hi python'

# %%
a=int(input('enter the number'))
b=int(input('enter the number'))
a+b
# Out:
# enter the number 9
# enter the number 4
# 13

# %%
a=int(input('enter the number'))
b=int(input('enter the number'))
c=a+b
print('the output will be',c)
# Out:
# enter the number 5
# enter the number 8
# the output will be 13

# %%
#take the user input
#do the mulitplication
a=int(input('enter the number'))
b=int(input('enter the number'))
c=a*b
print('the output will be',c)
# Out:
# enter the number 5
# enter the number 6
# the output will be 30

# %%
a=float(input('enter the number')) # we can give the int as well in float but it will take it as a decimal
b=float(input('enter the number'))
c=a*b
print('the output will be',c)
# Out:
# enter the number 5.3
# enter the number 6.2
# the output will be 32.86

# %%
a=eval(input('enter the number')) # we can use eval when we have float as well as the integer
b=eval(input('enter the number'))
c=a*b
print('the output will be',c)
# Out:
# enter the number 5.2
# enter the number 2
# the output will be 10.4

# %%
# Swapping numbers
a=9
b=6
a=a+b
b=a-b
a=a-b
print('a=',a)
print('b=',b)
# Out:
# a= 6
# b= 9

# %%
a=int(input('enter the number'))
b=int(input('enter the number'))
a=a+b
b=a-b
a=a-b
print('a=',a)
print('b=',b)
# Out:
# enter the number 9
# enter the number 6
# a= 6
# b= 9

# %% [markdown]
# a=9
# b=6
# a=a+b
# =9+6
# =15
# b=a-b
# =15-6
# =9
# a=a-b
# =15-9
# =6

# %%
a=9
b=6
c=a
a=b
b=c
print('a=',a)
print('b=',b)
# Out:
# a= 6
# b= 9

# %%
#string
a='python'
#indexing (p=0,y=1,t=2,h=3,o=4,n=5)
a[1]
# Out:
# 'y'

# %%
#positive indexing
a='welcome to python' # w=0,e=1,l=2,c=3,o=4,m=5,e=6, =7,t=8,o=9, =10,p=11,y=12,t=13,h=14,o=15,n=16
a[8]   #positive indexing start from left to right ,start from 0
# Out:
# 't'

# %%
#negative indexing
a='welcome to python' # w=-17,e=-16,l=-15,c=-14,o=-13,m=-12,e=-11, =-10,t=-9,o=-8, =-7,p=-6,y=-5,t=-4,h=-3,o=-2,n=-1
a[-5]   #negative indexing start from right to left,and begins with -1
# Out:
# 'y'

# %%
#slicing
a='welcome to python' #first number is starting,but last number will be not included means the indexed letter of last number will be not shown
a[13:15]
# Out:
# 'th'

# %%
a='welcome to python' 
a[0:7:2] #0 will be start,7 will be end,2 will be step index.step index means the step number indexed values will be not considered
# Out:
# 'wloe'

# %%
a='python'
a[0:6:5]
# Out:
# 'pn'

# %%
a='welcome to python' 
a[0:13:12]
# Out:
# 'wy'

# %%
a='welcome to python' 
a[-1:-3:-1]
# Out:
# 'no'

# %%
a='welcome to python'  # w=-17,e=-16,l=-15,c=-14,o=-13,m=-12,e=-11, =-10,t=-9,o=-8, =-7,p=-6,y=-5,t=-4,h=-3,o=-2,n=-1
a[-11:-15:-1]
# Out:
# 'emoc'

# %%
a='welcome to python'  # w=-17,e=-16,l=-15,c=-14,o=-13,m=-12,e=-11, =-10,t=-9,o=-8, =-7,p=-6,y=-5,t=-4,h=-3,o=-2,n=-1
a[-5:-3]
# Out:
# 'yt'

# %%
a[::] # print whole sentence
a[::-1] #reversing the sentence
# Out:
# 'nohtyp ot emoclew'

# %%
#Inbuilt method in str
a='welcome to python'
len(a)
# Out:
# 17

# %% [markdown]
# ## Uppercase (A-Z) ASCII Values 65-90
# ## Lowercase (a-z) ASCII Values 97-122

# %%
a='welcome to python'
min(a)
# Out:
# ' '

# %%
a='welcome to python'
max(a)
# Out:
# 'y'

# %%
'mumbai'>'pune'
# Out:
# False

# %%
'delhi'=='delhi'
# Out:
# True

# %%
sorted(a,reverse=True)
# Out:
# ['y',
#  'w',
#  't',
#  't',
#  'p',
#  'o',
#  'o',
#  'o',
#  'n',
#  'm',
#  'l',
#  'h',
#  'e',
#  'e',
#  'c',
#  ' ',
#  ' ']
